# %% [markdown]
# ### Import libraries

# %%
# %load_ext nb_black
# %matplotlib inline

import anndata as a
import vintools as v
import scdiffeq as sdq
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

from scatter import _ScatterPlot_Module as Scatter

# %% [markdown]
# ### Load some data

# %% [markdown]
# Code to prepare downsampled data:
#
# ```python
# adata = anndata.read_h5ad("../data/AnnData_train.WeinrebBenchmark.2020.h5ad")
# adata.obsm['X_SPRING'] = adata.obs[['SPRING-x', 'SPRING-y']].values
# adata = adata[::20]
# adata.write_h5ad("../AnnData.Weinreb.2020.DownSample.h5ad")
# ```

# %%
adata = a.read_h5ad("./LARRY_benchmark/AnnData.Weinreb.2020.DownSample.h5ad")
adata
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# AnnData object with n_obs × n_vars = 1352 × 25289
#     obs: 'LK_LSK', 'time', 'Library', 'Cell barcode', 'time_point', 'Starting population', 'Cell type annotation', 'Well', 'SPRING-x', 'SPRING-y', 'clonal_lineage', 'cytotrace', 'cytotrace_rank', 'cytotrace_GCS', 'lineage_tracing', 'gene_count', 'potency', 'n_counts', 'Source', 'mito_frac', 'time_info', 'state_info', 'cell_group_A', 'cell_group_B', 'traj_Neutrophil', 'traj_Monocyte', 'trajectory'
#     var: 'gene_ids'
#     uns: 'BM_ff', 'BMq', 'DE_Genes', 'DE_Genes_indices', 'E2', 'E2_mpp', 'LSKcells_d2', 'TF_indices', 'TFs', 'Y', 'd2_df', 'd2_idx', 'fate_names', 'filtered_gene_indices', 'mpp_ff', 'random_gene_indices', 'test', 'threepoint_lineages', 'train'
#     obsm: 'X_SPRING'

# %% [markdown]
# ### Start building the plot space

# %%
scatter = v.pl.ScatterPlot()
scatter.construct_layout(nplots=2)
scatter.style()

# %% [markdown]
# So our plot space is laid out. We made space for five different subplots. What can we put here?
#
# To simplify, we have **two main scenarios** we can consider:
#
# **Scenario 1**: **`[x, y]`** points colored by a continuous variable (i.e., a vector of floats such as the expression value of a gene or contnuous time.
#
# **Scenario 2**: **`[x, y]`** points colored by a categorical value such as an embedding colored by cluster assignment.
#
# For objects in AnnData, we want this to be automatically detected.
#
# For each subplot, we'll just provide an ordered list of assignments. If assignments are not provided where there are spaces, plots colored in lightgrey will be populated.

# %%
adata.var_names = adata.var.gene_ids
scatter.plot_data(
    adata, embedding="X_SPRING", variables_to_plot=["state_info", "Kdm1a"]
)
scatter.fig

# %% [markdown]
# Of course, we don't want to build such a plot, step-by-step every time. It's nice to have one single, in-line command such as:
#
# ```python
# v.pl.scatter(adata, 'variable')
# ```
#
# This is inuitive and satisfies the whole point of having presets: ease. This function would look something like the following, essentially wrapping the class we've created to make plots step-by-step and streamlining the notebook plotting process:
#
# ```python
#
# def _scatter(adata, embedding, variables_to_plot):
#
#     """"""
#
#     sc = Scatter.Scatter()
#     sc.construct_layout(nplots=len(variables_to_plot))
#     sc.style()
#     sc.plot_data(adata, embedding="X_SPRING", variables_to_plot=["state_info", "Kdm1a"])
#     plt.show()
#
# ```

# %%
v.pl.scatter(adata, embedding="X_SPRING", variables_to_plot=["state_info", "Kdm1a"])

# %%
# obs_keys = adata.obs_keys()
# var_keys = adata.var_keys()
adata.var_names = adata.var.gene_ids

# %%
_plot_gene(adata, gene="Kdm1a", embedding="X_SPRING")

# %%
arr = k.X.toarray()

# %%
arr.shape
# Out:
# (1352, 1)

# %%
emb = k.obsm["X_SPRING"].toarray()
# Out:
# array([[  179.864,   576.564],
#        [ 2808.243, -1453.517],
#        [ 1138.763, -2106.201],
#        ...,
#        [  -69.5  ,   585.36 ],
#        [ -503.037,   455.36 ],
#        [ 1467.992,  -323.079]])

# %%
adata.var_names = adata.var.gene_ids

# %%
variable = "Kdm1a"
if variable in adata.var_names:
    print(variable)
# Out:
# Kdm1a

# %%
adata.var_keys()
# Out:
# ['gene_ids']

# %%
var_keys[0]
# Out:
# 'gene_ids'

# %%
sc = Scatter.Scatter()
sc.construct_layout(nplots=1, figsize_height=0.2)
figs = plt.savefig("ScatterTesting.png")
plt.show()

# %%
sc.fig.get_size_inches()
# Out:
# array([25.6,  4.8])

# %%
ax0 = fig.add_subplot(gridspec[0, 3])
ax0.scatter(x=0.5, y=0.5, c="blue")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6f625bbf03fd> in <module>
# ----> 1 ax0 = fig.add_subplot(gridspec[0, 3])
#       2 ax0.scatter(x=0.5, y=0.5, c='blue')
#
# NameError: name 'fig' is not defined

# %%
gridspec[0,0], gridspec[0,1], gridspec[0,2]
# Out:
# (GridSpec(1, 4)[0:1, 0:1], GridSpec(1, 4)[0:1, 1:2], GridSpec(1, 4)[0:1, 2:3])

# %%
plot_count=0
axes = {}

for ax_i in range(nrows):
    axes[ax_i] = {}            
    for ax_j in range(ncols):

        plot_count += 1
        axes[ax_i][ax_j] = fig.add_subplot(gridspec[ax_i, ax_j])
        if plot_count >= nplots:
            break
plt.tight_layout()
plt.show()

# %%
    # construct plot surface
    self.hypers["fig"] = plt.figure(figsize=self.figsize)
    self.hypers["gridspec"] = GridSpec(
        nrows=self.nrows,
        ncols=self.ncols,
    )

# %%
def __init__(self, nplots=1, ncols=4, figsize=1):
    self.hypers = {}

    self.nplots = nplots
    self.ncols = ncols
    self.width = np.max([self.ncols, self.nplots])
    self.nrows = _calculate_nrows(self.nplots, self.ncols)
    self.figsize = np.array([4*self.width, 3.5*self.nrows]) * figsize

    # construct plot surface
    self.hypers["fig"] = plt.figure(figsize=self.figsize)
    self.hypers["gridspec"] = GridSpec(
        nrows=self.nrows,
        ncols=self.ncols,
    )

    axes = {}

    plot_count = 0
    for ax_i in range(self.nrows):
        axes[ax_i] = {}            
        for ax_j in range(self.ncols):

            plot_count += 1
            axes[ax_i][ax_j] = self.hypers["fig"].add_subplot(self.hypers["gridspec"][ax_i, ax_j])
            if plot_count >= nplots:
                break
    plt.tight_layout()
    plt.show()

# %%
x_component, y_component = data[:, 0], data[:, 1]

# construct plot surface
fig = plt.figure(figsize=figsize)
gridspec = GridSpec(
    nrows=2,
    ncols=3,
    height_ratios=[0.15, 1],
    width_ratios=[0.2, 1, 0.075],
    wspace=0.2,
    hspace=0.1,
)

x_component_histogram = fig.add_subplot(gridspec[0, 1])
x_component_bins = x_component_histogram.hist(
    x_component,
    bins=n_bins,
    color=histcolor,
    alpha=histalpha,
)

# %%
import matplotlib

# %%
# Out:
# [6.4, 4.8]

# %%
figsize : (float, float), default: :rc:`figure.figsize`
    Width, height in inches.

# %%
# package imports #
# --------------- #
# import matplotlib
# import matplotlib.font_manager
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.colorbar import Colorbar

# local imports #
# ------------- #
# from ._modify_ax_spines import _modify_ax_spines # v.pl.ax_spines()
# from ._set_minimal_ticks import _set_minimal_ticks # v.pl.set_minimal_ticks()


def _calculate_nrows(nplots, ncols=4):

    return math.ceil(nplots / ncols)


# matplotlib presets #
# ------------------ #
font = {"size": 12}
matplotlib.rc(font)
matplotlib.rcParams["font.sans-serif"] = "Arial"
matplotlib.rcParams["font.family"] = "sans-serif"


class ScatterPlot:
    def __init__(self, nplots=1, ncols=4, figsize=1):

        """
        Parameters:
        -----------

        Returns:
        --------

        Notes:
        ------
        nb_width = 16
        Saves "hypers as a dict with potentially useful info...
        """

        self.hypers = {}

        self.nplots = nplots
        self.ncols = ncols
        self.width = np.max([self.ncols, self.nplots])
        self.nrows = _calculate_nrows(self.nplots, self.ncols)
        self.figsize = np.array([4 * self.width, 3.5 * self.nrows]) * figsize

        # construct plot surface
        self.hypers["fig"] = plt.figure(figsize=self.figsize)
        self.hypers["gridspec"] = GridSpec(
            nrows=self.nrows,
            ncols=self.ncols,
        )

        axes = {}

        plot_count = 0
        for ax_i in range(self.nrows):
            axes[ax_i] = {}
            for ax_j in range(self.ncols):

                plot_count += 1
                axes[ax_i][ax_j] = self.hypers["fig"].add_subplot(
                    self.hypers["gridspec"][ax_i, ax_j]
                )
                if plot_count >= nplots:
                    break
        plt.tight_layout()
        plt.show()

    def continuous(
        self,
    ):

        """

        Make a scatter plot colored by continuous quantitative values.

        Parameters:
        -----------

        Returns:
        --------

        Notes:
        ------

        """

        print("Making a continuous scatterplot")

    def categorical(
        self,
    ):

        """
        Parameters:
        -----------

        Returns:
        --------

        Notes:
        ------

        """

        print("Making a categorical scatterplot")


def scatter(continuous=False, categorical=False):

    """
    Parameters:
    -----------

    Returns:
    --------

    Notes:
    ------

    """

    plot = ScatterPlot()

    if continuous:
        plot.continuous()

    elif categorical:
        plot.categorical()
    else:
        print("vanilla")

# %%
sc = ScatterPlot(nplots=2, figsize=1.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c81f749a87f7> in <module>
# ----> 1 sc = ScatterPlot(nplots=2, figsize=1.2)
#
# <ipython-input-7-aa22c9f10dc0> in __init__(self, nplots, ncols, figsize)
#      48         self.ncols = ncols
#      49         self.width = np.max([self.ncols, self.nplots])
# ---> 50         self.nrows = _calculate_nrows(self.nplots, self.ncols)
#      51         self.figsize = np.array([4*self.width, 3.5*self.nrows]) * figsize
#      52
#
# <ipython-input-7-aa22c9f10dc0> in _calculate_nrows(nplots, ncols)
#      16 def _calculate_nrows(nplots, ncols=4):
#      17
# ---> 18     return math.ceil(nplots / ncols)
#      19
#      20
#
# NameError: name 'math' is not defined

# %%
sc.hypers['gridspec']
# Out:
# GridSpec(1, 4)

# %%
sc.hypers.keys()
# Out:
# dict_keys(['fig', 'gridspec'])

# %%
import math

# %% [markdown]
# ### Functionality to add:
# - colorschemes
# - outlines

# %%
# package imports #
# --------------- #
import numpy as np
import vintools as v

import matplotlib.pyplot as plt
import matplotlib.font_manager




def _simulation_plot_presets(
    x,
    y,
    plot_title=None,
    x_lab="$x$",
    y_lab="$y$",
    title_fontsize=16,
    label_fontsize=14,
    figsize=(6, 5),
    **kwargs
):

    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(1, 1, 1)

    spines = v.pl.ax_spines(ax)
    spines.set_color("grey")
    spines.delete(select_spines=["top", "right"])
    spines.set_position(position_type="axes", amount=-0.05)

    v.pl.set_minimal_ticks(ax, x, y)

    ax.set_title(plot_title, y=1.05, fontsize=title_fontsize)
    ax.set_xlabel("$x$", size=label_fontsize)
    ax.set_ylabel("$y$", size=label_fontsize)
    ax.scatter(x, y, **kwargs)
    plt.grid(zorder=0, c="lightgrey", alpha=0.5)
    plt.show()

def _plot(self, c="time", savefigname=None, **kwargs):

    X = self.adata.X
    if c == "time":
        c = self.adata.obs.time

    _simulation_plot_presets(X[:, 0], X[:, 1], c=c, **kwargs)
    if savefigname:
        out = plt.savefig(savefigname)

# %% [markdown]
# To plot the default embedding from AnnData:

# %%
v.pl.scatter(adata)

# %% [markdown]
# You can also eplicitely set **`x`** and **`y`** parameters for non-AnnData plots:

# %%
v.pl.scatter(x=x_vals, y=y_va)

# %%
scatter(True, False)
# Out:
# Making a continuous scatterplot
